# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.deterministic import DeterministicProcess
from time import time

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from skopt import BayesSearchCV
from xgboost import XGBRegressor

# %% [markdown]
# <h3>Steps to be followed</h3>
# <ol>
#     <li>Read in data</li>
#     <li>Find starting and ending dates for train and test sets</li>
#     <li>Create date range containing all dates from start to end of training set with hourly frequency</li>
#     <li>Create a feature for time data with hourly frequency</li>
#     <li>Create lag features</li>
# </ol>

# %% [markdown]
# <h4>Reading Dataset</h4>

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

train.date=pd.to_datetime(train.date)
test.date=pd.to_datetime(test.date)

# %% [markdown]
# <h4>Sorting train data by date and hour</h4>

# %%
train=train.sort_values(by=['date','hour'])
display(train.head())
print('train-shape: ',train.shape)
display(test.head())
print('test-shape: ',test.shape)
# Out:
#         date  hour  demand
# 0 2018-08-18     9      91
# 1 2018-08-18    10      21
# 2 2018-08-18    13      23
# 3 2018-08-18    14     104
# 4 2018-08-18    15      81
# train-shape:  (18247, 3)
#         date  hour
# 0 2021-03-01     0
# 1 2021-03-01     1
# 2 2021-03-01     2
# 3 2021-03-01     3
# 4 2021-03-01     5
# test-shape:  (7650, 2)

# %% [markdown]
# <h4>Finding starting and ending dates for train and test sets</h4>

# %%
for title,df in [('Train',train),('Test',test)]:
    print(title+'\n'+'--'*30)
    print('Starting-date: ',df['date'].min())
    print('Ending-date: ',df['date'].max())
    print('\n')
# Out:
# Train
# ------------------------------------------------------------
# Starting-date:  2018-08-18 00:00:00
# Ending-date:  2021-02-28 00:00:00
#
#
# Test
# ------------------------------------------------------------
# Starting-date:  2021-03-01 00:00:00
# Ending-date:  2022-03-28 00:00:00

# %%
# Generating hourly daterange for training data with hourly frequency
df1=pd.DataFrame({'combined_date':pd.date_range(start='2018-08-18',end='2021-02-28',freq='H')})

# %%
# merging hour column and datetime column
train['combined_date']=train.date.apply(lambda x:str(x))+' '+train.hour.apply(lambda x:str(x))+':00:00'
test['combined_date']=test.date.apply(lambda x:str(x))+' '+test.hour.apply(lambda x:str(x))+':00:00'

# converting new combined date column to datetime
train['combined_date']=pd.to_datetime(train['combined_date'])
test['combined_date']=pd.to_datetime(test['combined_date'])

# %%
# Merging df1 with train to get the full time index
df_train=pd.merge(df1,train,on='combined_date',how='left').drop(['date','hour'],axis=1).set_index('combined_date')
del(df1)

# filling NaN values with 0 since all missing timestamps can be assumed to have zero demand
df_train=df_train.fillna(0)

display(df_train.head())
print(df_train.shape)
# Out:
#                      demand
# combined_date
# 2018-08-18 00:00:00     0.0
# 2018-08-18 01:00:00     0.0
# 2018-08-18 02:00:00     0.0
# 2018-08-18 03:00:00     0.0
# 2018-08-18 04:00:00     0.0
# (22201, 1)

# %%
# creating a new time feature from the combined date column
dp=DeterministicProcess(index=df_train.index,
                       constant=False,
                       order=1,
                       drop=True)
df1=dp.in_sample().rename(columns={'trend':'time1'})
df_train=pd.merge(df1,df_train,on='combined_date',how='inner')
df_train.head()
# Out:
#                      time1  demand
# combined_date
# 2018-08-18 00:00:00    1.0     0.0
# 2018-08-18 01:00:00    2.0     0.0
# 2018-08-18 02:00:00    3.0     0.0
# 2018-08-18 03:00:00    4.0     0.0
# 2018-08-18 04:00:00    5.0     0.0

# %%
df_train['demand'].plot(figsize=(12,5),alpha=0.75,color='#827397')

# Setting title
plt.title('Overall Data Distribution\n',fontdict={'fontsize':20,'fontweight':5,'color':'#069A8E'})

# setting xlabels and ylabels
plt.xlabel('Time',fontdict={'fontsize':14,'fontweight':5,'color':'#069A8E'})
plt.ylabel('Demand',fontdict={'fontsize':14,'fontweight':5,'color':'#069A8E'});

# %% [markdown]
# It looks like data for the month of December,2020 is missing

# %%
# Plotting data for december for 3 years
december_2018=df_train.loc[(df_train.index.year==2018) &(df_train.index.month==12)].reset_index()
december_2019=df_train.loc[(df_train.index.year==2019) &(df_train.index.month==12)].reset_index()
december_2020=df_train.loc[(df_train.index.year==2020) &(df_train.index.month==12)].reset_index()

december_2018['demand'].plot(figsize=(12,5),label='december_2018',color='orange')
december_2019['demand'].plot(figsize=(12,5),label='december_2019',color='blue',alpha=0.5)
december_2020['demand'].plot(figsize=(12,5),label='december_2020',color='green',alpha=0.5)


plt.legend();

# %% [markdown]
# December,2020 has missing data from 2020-12-01 to 2020-12-26. So these values will be replaced by average values from previous years

# %%
# Imputing missing values in december 2020 with average values from previous years

imputed_demand=0.5*(df_train.loc['2018-12-01':'2018-12-26','demand'].values+\
                    df_train.loc['2019-12-01':'2019-12-26','demand'].values)

df_train.loc['2020-12-01':'2020-12-26','demand']=imputed_demand

# %%
# Plotting the corrected data
df_train['demand'].plot(figsize=(12,5),alpha=0.75,color='#827397')
# Out:
# <AxesSubplot:xlabel='combined_date'>

# %% [markdown]
# <h4>Creating Lag Features</h4>

# %%
def create_lag_features(df,col_names,n_lags=20):
    '''
    Creates lag_features from a list of features for a data frame
    
    Inputs
    ------------------------------
    df- the daataframe
    col_name--list of strings indicating column names from which features need to be created
    n_lags: number of lags to be created
    
    Outputs
    ------------------------------
    consolidated dataframe containing the lag features
    '''
    
    data=df.copy(deep=True)
    
    for col in col_names:
        for i in range(1,n_lags+1):
            data.loc[:,col+'_lag_'+str(i)]=data[col].shift(i)
    
    # fill NaN values with 0
    data.fillna(0,inplace=True)
    return data

# %% [markdown]
# <h4>Train-test-split</h4>
# <p>
#     Since the forecast needs to be made only for the month of March, test and validation sets will also be of 1 month each
# </p>

# %%
df_train1=df_train.loc[:'2021-01-31']
X_test=df_train.loc['2021-02-01':]

print(df_train1.shape)
print(X_test.shape)
# Out:
# (21552, 2)
# (649, 2)

# %%
# creating lag features
df_train2=create_lag_features(df_train1,['demand'],n_lags=30)

# create validation_set
X_val=df_train2.loc['2021-01-01':'2021-01-31'].drop('demand',axis=1)
y_val=df_train2.loc['2021-01-01':'2021-01-31','demand']

# Create training set
X_train=df_train2.loc[:'2020-12-31'].drop('demand',axis=1)
y_train=df_train2.loc[:'2020-12-31','demand']

# %%
# Exporting df_train2 for online training
# df_train2.to_csv('df_train2.csv')

# %% [markdown]
# <h3>Model Building</h3>

# %% [markdown]
# <h4>Linear Model</h4>

# %%
lr_model=LinearRegression()

lr_model.fit(X_train,y_train)
pred=pd.Series(lr_model.predict(X_val),index=y_val.index)
rmse=np.sqrt(mean_squared_error(y_val,pred))
print('val_RMSE: ',rmse)
# Out:
# val_RMSE:  35.847363169506735

# %%
y_val.plot(figsize=(12,5),alpha=0.7,label='y_val');
pred.plot(alpha=1,color='orange',label='y_val_pred')
plt.legend();

# %% [markdown]
# <h4>XGBoost</h4>

# %%
xgb_model = XGBRegressor(
            n_estimators=1000,
            max_depth=5,
            min_child_weight=3,
            learning_rate=0.01,
            gamma=0.2,
            colsample_bytree=0.2)


xgb_model.fit(
    X_train, 
    y_train, 
    eval_metric="rmse", 
    eval_set=[(X_train, y_train), (X_val, y_val)], 
    verbose=True, 
    early_stopping_rounds = 10)
# Out:
# [0]	validation_0-rmse:76.61796	validation_1-rmse:85.68007
# [1]	validation_0-rmse:76.06466	validation_1-rmse:85.06458
# [2]	validation_0-rmse:75.50005	validation_1-rmse:84.44544
# [3]	validation_0-rmse:74.95080	validation_1-rmse:83.86497
# [4]	validation_0-rmse:74.39813	validation_1-rmse:83.26625
# [5]	validation_0-rmse:73.85214	validation_1-rmse:82.67226
# [6]	validation_0-rmse:73.35053	validation_1-rmse:82.13927
# [7]	validation_0-rmse:72.80798	validation_1-rmse:81.53913
# [8]	validation_0-rmse:72.31143	validation_1-rmse:81.01398
# [9]	validation_0-rmse:71.81874	validation_1-rmse:80.49706
# [10]	validation_0-rmse:71.34285	validation_1-rmse:79.99398
# [11]	validation_0-rmse:70.83047	validation_1-rmse:79.42867
# [12]	validation_0-rmse:70.30654	validation_1-rmse:78.85335
# [13]	validation_0-rmse:69.81535	validation_1-rmse:78.31787
# [14]	validation_0-rmse:69.36452	validation_1-rmse:77.84218
# [15]	validation_0-rmse:68.87534	validation_1-rmse:77.29691
# [16]	validation_0-rmse:68.41544	validation_1-rmse:76.79417
# [17]	validation_0-rmse:67.91489	validation_1-rmse:76.23153
# [18]	validation_0-rmse:67.41857	validation_1-rmse:75.67541
# [19]	validation_0-rmse:66.94460	validation_1-rmse:75.14475
# [20]	validation_0-rmse:66.48429	validation_1-rmse:74.63303
# [21]	validation_0-rmse:66.02987	validation_1-rmse:74.13261
# [22]	validation_0-rmse:65.60635	validation_1-rmse:73.66615
# [23]	validation_0-rmse:65.16578	validation_1-rmse:73.17637
# [24]	validation_0-rmse:64.69979	validation_1-rmse:72.65196
# [25]	validation_0-rmse:64.28254	validation_1-rmse:72.20329
# [26]	validation_0-rmse:63.83586	validation_1-rmse:71.70031
# [27]	validation_0-rmse:63.39451	validation_1-rmse:71.20443
# [28]	validation_0-rmse:62.98634	validation_1-rmse:70.75930
# [29]	validation_0-rmse:62.57312	validation_1-rmse:70.30019
# [30]	validation_0-rmse:62.14488	validation_1-rmse:69.82140
# [31]	validation_0-rmse:61.77080	validation_1-rmse:69.41414
# [32]	validation_0-rmse:61.35106	validation_1-rmse:68.94263
# [33]	validation_0-rmse:60.95260	validation_1-rmse:68.50005
# [34]	validation_0-rmse:60.57840	validation_1-rmse:68.08966
# [35]	validation_0-rmse:60.21637	validation_1-rmse:67.68624
# [36]	validation_0-rmse:59.82201	validation_1-rmse:67.25272
# [37]	validation_0-rmse:59.42764	validation_1-rmse:66.80533
# [38]	validation_0-rmse:59.03194	validation_1-rmse:66.35266
# [39]	validation_0-rmse:58.67761	validation_1-rmse:65.95818
# [40]	validation_0-rmse:58.31872	validation_1-rmse:65.56135
# [41]	validation_0-rmse:57.97034	validation_1-rmse:65.18475
# [42]	validation_0-rmse:57.60397	validation_1-rmse:64.76624
# [43]	validation_0-rmse:57.27278	validation_1-rmse:64.39179
# [44]	validation_0-rmse:56.92953	validation_1-rmse:64.01407
# [45]	validation_0-rmse:56.57742	validation_1-rmse:63.61689
# [46]	validation_0-rmse:56.24137	validation_1-rmse:63.24025
# [47]	validation_0-rmse:55.92325	validation_1-rmse:62.88908
# [48]	validation_0-rmse:55.58943	validation_1-rmse:62.51846
# [49]	validation_0-rmse:55.26783	validation_1-rmse:62.15580
# [50]	validation_0-rmse:54.97397	validation_1-rmse:61.83537
# [51]	validation_0-rmse:54.67180	validation_1-rmse:61.50004
# [52]	validation_0-rmse:54.34819	validation_1-rmse:61.13898
# [53]	validation_0-rmse:54.04176	validation_1-rmse:60.79945
# [54]	validation_0-rmse:53.74077	validation_1-rmse:60.45884
# [55]	validation_0-rmse:53.44138	validation_1-rmse:60.11325
# [56]	validation_0-rmse:53.13248	validation_1-rmse:59.76637
# [57]	validation_0-rmse:52.86430	validation_1-rmse:59.46917
# [58]	validation_0-rmse:52.57189	validation_1-rmse:59.13671
# [59]	validation_0-rmse:52.29195	validation_1-rmse:58.82542
# [60]	validation_0-rmse:52.03608	validation_1-rmse:58.54725
# [61]	validation_0-rmse:51.77004	validation_1-rmse:58.24586
# [62]	validation_0-rmse:51.49812	validation_1-rmse:57.93226
# [63]	validation_0-rmse:51.22433	validation_1-rmse:57.62654
# [64]	validation_0-rmse:50.96051	validation_1-rmse:57.31760
# [65]	validation_0-rmse:50.69846	validation_1-rmse:57.00706
# [66]	validation_0-rmse:50.42652	validation_1-rmse:56.69785
# [67]	validation_0-rmse:50.17168	validation_1-rmse:56.40305
# [68]	validation_0-rmse:49.90340	validation_1-rmse:56.09095
# [69]	validation_0-rmse:49.63673	validation_1-rmse:55.78498
# [70]	validation_0-rmse:49.40231	validation_1-rmse:55.51501
# [71]	validation_0-rmse:49.17189	validation_1-rmse:55.24988
# [72]	validation_0-rmse:48.92003	validation_1-rmse:54.96256
# [73]	validation_0-rmse:48.70348	validation_1-rmse:54.72049
# [74]	validation_0-rmse:48.46427	validation_1-rmse:54.44356
# [75]	validation_0-rmse:48.23451	validation_1-rmse:54.18913
# [76]	validation_0-rmse:48.01933	validation_1-rmse:53.94562
# [77]	validation_0-rmse:47.79704	validation_1-rmse:53.69580
# [78]	validation_0-rmse:47.57576	validation_1-rmse:53.45272
# [79]	validation_0-rmse:47.35446	validation_1-rmse:53.20374
# [80]	validation_0-rmse:47.14006	validation_1-rmse:52.95139
# [81]	validation_0-rmse:46.90859	validation_1-rmse:52.68845
# [82]	validation_0-rmse:46.70410	validation_1-rmse:52.45229
# [83]	validation_0-rmse:46.47952	validation_1-rmse:52.19163
# [84]	validation_0-rmse:46.28341	validation_1-rmse:51.96896
# [85]	validation_0-rmse:46.10219	validation_1-rmse:51.75784
# [86]	validation_0-rmse:45.90771	validation_1-rmse:51.54122
# [87]	validation_0-rmse:45.70766	validation_1-rmse:51.30765
# [88]	validation_0-rmse:45.53593	validation_1-rmse:51.13170
# [89]	validation_0-rmse:45.35097	validation_1-rmse:50.91838
# [90]	validation_0-rmse:45.14514	validation_1-rmse:50.67722
# [91]	validation_0-rmse:44.95426	validation_1-rmse:50.45826
# [92]	validation_0-rmse:44.75597	validation_1-rmse:50.23642
# [93]	validation_0-rmse:44.56886	validation_1-rmse:50.01528
# [94]	validation_0-rmse:44.37352	validation_1-rmse:49.78777
# [95]	validation_0-rmse:44.22071	validation_1-rmse:49.61750
# [96]	validation_0-rmse:44.06333	validation_1-rmse:49.44214
# [97]	validation_0-rmse:43.87882	validation_1-rmse:49.22691
# [98]	validation_0-rmse:43.71815	validation_1-rmse:49.03594
# [99]	validation_0-rmse:43.54697	validation_1-rmse:48.84185
# [100]	validation_0-rmse:43.36889	validation_1-rmse:48.62955
# [101]	validation_0-rmse:43.20744	validation_1-rmse:48.44807
# [102]	validation_0-rmse:43.06662	validation_1-rmse:48.28933
# [103]	validation_0-rmse:42.90899	validation_1-rmse:48.11173
# [104]	validation_0-rmse:42.73723	validation_1-rmse:47.91587
# [105]	validation_0-rmse:42.58889	validation_1-rmse:47.75030
# [106]	validation_0-rmse:42.44391	validation_1-rmse:47.57597
# [107]	validation_0-rmse:42.29240	validation_1-rmse:47.39485
# [108]	validation_0-rmse:42.15264	validation_1-rmse:47.22908
# [109]	validation_0-rmse:42.03519	validation_1-rmse:47.09778
# [110]	validation_0-rmse:41.88329	validation_1-rmse:46.91617
# [111]	validation_0-rmse:41.74293	validation_1-rmse:46.74609
# [112]	validation_0-rmse:41.60652	validation_1-rmse:46.57600
# [113]	validation_0-rmse:41.45773	validation_1-rmse:46.39780
# [114]	validation_0-rmse:41.33222	validation_1-rmse:46.25085
# [115]	validation_0-rmse:41.20947	validation_1-rmse:46.11246
# [116]	validation_0-rmse:41.08309	validation_1-rmse:45.97218
# [117]	validation_0-rmse:40.95887	validation_1-rmse:45.83207
# [118]	validation_0-rmse:40.83789	validation_1-rmse:45.69162
# [119]	validation_0-rmse:40.71468	validation_1-rmse:45.54895
# [120]	validation_0-rmse:40.58727	validation_1-rmse:45.39450
# [121]	validation_0-rmse:40.45628	validation_1-rmse:45.23895
# [122]	validation_0-rmse:40.34083	validation_1-rmse:45.11100
# [123]	validation_0-rmse:40.20880	validation_1-rmse:44.95701
# [124]	validation_0-rmse:40.09512	validation_1-rmse:44.81639
# [125]	validation_0-rmse:39.98453	validation_1-rmse:44.69144
# [126]	validation_0-rmse:39.87387	validation_1-rmse:44.56447
# [127]	validation_0-rmse:39.76265	validation_1-rmse:44.42923
# [128]	validation_0-rmse:39.65838	validation_1-rmse:44.30244
# [129]	validation_0-rmse:39.55792	validation_1-rmse:44.18766
# [130]	validation_0-rmse:39.45511	validation_1-rmse:44.07070
# [131]	validation_0-rmse:39.35822	validation_1-rmse:43.95392
# [132]	validation_0-rmse:39.25555	validation_1-rmse:43.83158
# [133]	validation_0-rmse:39.14193	validation_1-rmse:43.69846
# [134]	validation_0-rmse:39.03109	validation_1-rmse:43.56720
# [135]	validation_0-rmse:38.94814	validation_1-rmse:43.47408
# [136]	validation_0-rmse:38.85630	validation_1-rmse:43.36200
# [137]	validation_0-rmse:38.76515	validation_1-rmse:43.25798
# [138]	validation_0-rmse:38.65941	validation_1-rmse:43.13190
# [139]	validation_0-rmse:38.57320	validation_1-rmse:43.02369
# [140]	validation_0-rmse:38.46961	validation_1-rmse:42.90509
# [141]	validation_0-rmse:38.38814	validation_1-rmse:42.80793
# [142]	validation_0-rmse:38.29784	validation_1-rmse:42.70524
# [143]	validation_0-rmse:38.21961	validation_1-rmse:42.61628
# [144]	validation_0-rmse:38.13776	validation_1-rmse:42.52255
# [145]	validation_0-rmse:38.04121	validation_1-rmse:42.40450
# [146]	validation_0-rmse:37.96356	validation_1-rmse:42.31186
# [147]	validation_0-rmse:37.88822	validation_1-rmse:42.22435
# [148]	validation_0-rmse:37.81487	validation_1-rmse:42.12853
# [149]	validation_0-rmse:37.74187	validation_1-rmse:42.04008
# [150]	validation_0-rmse:37.65095	validation_1-rmse:41.93478
# [151]	validation_0-rmse:37.57826	validation_1-rmse:41.84449
# [152]	validation_0-rmse:37.50842	validation_1-rmse:41.76134
# [153]	validation_0-rmse:37.43866	validation_1-rmse:41.67524
# [154]	validation_0-rmse:37.35890	validation_1-rmse:41.57713
# [155]	validation_0-rmse:37.29843	validation_1-rmse:41.49539
# [156]	validation_0-rmse:37.23563	validation_1-rmse:41.41930
# [157]	validation_0-rmse:37.16443	validation_1-rmse:41.32875
# [158]	validation_0-rmse:37.09317	validation_1-rmse:41.23806
# [159]	validation_0-rmse:37.02117	validation_1-rmse:41.14599
# [160]	validation_0-rmse:36.95917	validation_1-rmse:41.06916
# [161]	validation_0-rmse:36.88218	validation_1-rmse:40.97786
# [162]	validation_0-rmse:36.81813	validation_1-rmse:40.90524
# [163]	validation_0-rmse:36.74511	validation_1-rmse:40.81337
# [164]	validation_0-rmse:36.67826	validation_1-rmse:40.73487
# [165]	validation_0-rmse:36.61805	validation_1-rmse:40.66208
# [166]	validation_0-rmse:36.55666	validation_1-rmse:40.59547
# [167]	validation_0-rmse:36.49201	validation_1-rmse:40.51495
# [168]	validation_0-rmse:36.44270	validation_1-rmse:40.45455
# [169]	validation_0-rmse:36.37522	validation_1-rmse:40.37451
# [170]	validation_0-rmse:36.30763	validation_1-rmse:40.28763
# [171]	validation_0-rmse:36.25172	validation_1-rmse:40.22055
# [172]	validation_0-rmse:36.20187	validation_1-rmse:40.15100
# [173]	validation_0-rmse:36.15260	validation_1-rmse:40.09341
# [174]	validation_0-rmse:36.09758	validation_1-rmse:40.03451
# [175]	validation_0-rmse:36.04869	validation_1-rmse:39.96806
# [176]	validation_0-rmse:35.98705	validation_1-rmse:39.89502
# [177]	validation_0-rmse:35.93330	validation_1-rmse:39.83816
# [178]	validation_0-rmse:35.88268	validation_1-rmse:39.77582
# [179]	validation_0-rmse:35.83320	validation_1-rmse:39.71914
# [180]	validation_0-rmse:35.78898	validation_1-rmse:39.66655
# [181]	validation_0-rmse:35.72885	validation_1-rmse:39.59533
# [182]	validation_0-rmse:35.68760	validation_1-rmse:39.54504
# [183]	validation_0-rmse:35.63927	validation_1-rmse:39.49236
# [184]	validation_0-rmse:35.59139	validation_1-rmse:39.43800
# [185]	validation_0-rmse:35.53502	validation_1-rmse:39.36900
# [186]	validation_0-rmse:35.49542	validation_1-rmse:39.32373
# [187]	validation_0-rmse:35.45189	validation_1-rmse:39.27562
# [188]	validation_0-rmse:35.41836	validation_1-rmse:39.23950
# [189]	validation_0-rmse:35.37736	validation_1-rmse:39.19313
# [190]	validation_0-rmse:35.33033	validation_1-rmse:39.13405
# [191]	validation_0-rmse:35.28656	validation_1-rmse:39.08954
# [192]	validation_0-rmse:35.24511	validation_1-rmse:39.04315
# [193]	validation_0-rmse:35.20067	validation_1-rmse:38.98570
# [194]	validation_0-rmse:35.15514	validation_1-rmse:38.93163
# [195]	validation_0-rmse:35.11330	validation_1-rmse:38.88521
# [196]	validation_0-rmse:35.07578	validation_1-rmse:38.84203
# [197]	validation_0-rmse:35.04388	validation_1-rmse:38.80259
# [198]	validation_0-rmse:35.00966	validation_1-rmse:38.76424
# [199]	validation_0-rmse:34.96977	validation_1-rmse:38.71403
# [200]	validation_0-rmse:34.93457	validation_1-rmse:38.66956
# [201]	validation_0-rmse:34.90156	validation_1-rmse:38.62872
# [202]	validation_0-rmse:34.85701	validation_1-rmse:38.57574
# [203]	validation_0-rmse:34.82304	validation_1-rmse:38.53372
# [204]	validation_0-rmse:34.79428	validation_1-rmse:38.50047
# [205]	validation_0-rmse:34.75814	validation_1-rmse:38.45697
# [206]	validation_0-rmse:34.71623	validation_1-rmse:38.40569
# [207]	validation_0-rmse:34.68056	validation_1-rmse:38.36421
# [208]	validation_0-rmse:34.65252	validation_1-rmse:38.32947
# [209]	validation_0-rmse:34.61186	validation_1-rmse:38.27616
# [210]	validation_0-rmse:34.57982	validation_1-rmse:38.24020
# [211]	validation_0-rmse:34.54817	validation_1-rmse:38.20494
# [212]	validation_0-rmse:34.52214	validation_1-rmse:38.17429
# [213]	validation_0-rmse:34.48658	validation_1-rmse:38.13857
# [214]	validation_0-rmse:34.45800	validation_1-rmse:38.10385
# [215]	validation_0-rmse:34.42018	validation_1-rmse:38.05994
# [216]	validation_0-rmse:34.38318	validation_1-rmse:38.01677
# [217]	validation_0-rmse:34.34977	validation_1-rmse:37.97467
# [218]	validation_0-rmse:34.32642	validation_1-rmse:37.95035
# [219]	validation_0-rmse:34.29424	validation_1-rmse:37.91175
# [220]	validation_0-rmse:34.26728	validation_1-rmse:37.88244
# [221]	validation_0-rmse:34.23536	validation_1-rmse:37.84321
# [222]	validation_0-rmse:34.20735	validation_1-rmse:37.81274
# [223]	validation_0-rmse:34.18469	validation_1-rmse:37.78757
# [224]	validation_0-rmse:34.16077	validation_1-rmse:37.75750
# [225]	validation_0-rmse:34.13087	validation_1-rmse:37.72023
# [226]	validation_0-rmse:34.10793	validation_1-rmse:37.69385
# [227]	validation_0-rmse:34.07473	validation_1-rmse:37.65476
# [228]	validation_0-rmse:34.04265	validation_1-rmse:37.61948
# [229]	validation_0-rmse:34.01085	validation_1-rmse:37.58240
# [230]	validation_0-rmse:33.98793	validation_1-rmse:37.55662
# [231]	validation_0-rmse:33.95716	validation_1-rmse:37.51782
# [232]	validation_0-rmse:33.93446	validation_1-rmse:37.49337
# [233]	validation_0-rmse:33.91417	validation_1-rmse:37.46504
# [234]	validation_0-rmse:33.89596	validation_1-rmse:37.44435
# [235]	validation_0-rmse:33.87378	validation_1-rmse:37.42029
# [236]	validation_0-rmse:33.84483	validation_1-rmse:37.38485
# [237]	validation_0-rmse:33.82359	validation_1-rmse:37.35761
# [238]	validation_0-rmse:33.80180	validation_1-rmse:37.33566
# [239]	validation_0-rmse:33.78233	validation_1-rmse:37.30944
# [240]	validation_0-rmse:33.76327	validation_1-rmse:37.28599
# [241]	validation_0-rmse:33.74365	validation_1-rmse:37.26194
# [242]	validation_0-rmse:33.71589	validation_1-rmse:37.23039
# [243]	validation_0-rmse:33.68927	validation_1-rmse:37.20034
# [244]	validation_0-rmse:33.66381	validation_1-rmse:37.16992
# [245]	validation_0-rmse:33.64827	validation_1-rmse:37.15130
# [246]	validation_0-rmse:33.62897	validation_1-rmse:37.12952
# [247]	validation_0-rmse:33.60787	validation_1-rmse:37.09652
# [248]	validation_0-rmse:33.58291	validation_1-rmse:37.06881
# [249]	validation_0-rmse:33.56442	validation_1-rmse:37.05087
# [250]	validation_0-rmse:33.54567	validation_1-rmse:37.02685
# [251]	validation_0-rmse:33.52551	validation_1-rmse:37.00196
# [252]	validation_0-rmse:33.50391	validation_1-rmse:36.97706
# [253]	validation_0-rmse:33.48852	validation_1-rmse:36.95768
# [254]	validation_0-rmse:33.46930	validation_1-rmse:36.93282
# [255]	validation_0-rmse:33.45305	validation_1-rmse:36.91456
# [256]	validation_0-rmse:33.43642	validation_1-rmse:36.89610
# [257]	validation_0-rmse:33.42207	validation_1-rmse:36.88037
# [258]	validation_0-rmse:33.39999	validation_1-rmse:36.85477
# [259]	validation_0-rmse:33.38434	validation_1-rmse:36.84097
# [260]	validation_0-rmse:33.36908	validation_1-rmse:36.82373
# [261]	validation_0-rmse:33.35411	validation_1-rmse:36.80956
# [262]	validation_0-rmse:33.34168	validation_1-rmse:36.79971
# [263]	validation_0-rmse:33.32542	validation_1-rmse:36.78637
# [264]	validation_0-rmse:33.31135	validation_1-rmse:36.77233
# [265]	validation_0-rmse:33.29060	validation_1-rmse:36.74873
# [266]	validation_0-rmse:33.27364	validation_1-rmse:36.73143
# [267]	validation_0-rmse:33.25626	validation_1-rmse:36.71223
# [268]	validation_0-rmse:33.24131	validation_1-rmse:36.69768
# [269]	validation_0-rmse:33.22165	validation_1-rmse:36.67291
# [270]	validation_0-rmse:33.20429	validation_1-rmse:36.64819
# [271]	validation_0-rmse:33.19483	validation_1-rmse:36.63954
# [272]	validation_0-rmse:33.17587	validation_1-rmse:36.61639
# [273]	validation_0-rmse:33.15982	validation_1-rmse:36.59814
# [274]	validation_0-rmse:33.14004	validation_1-rmse:36.57523
# [275]	validation_0-rmse:33.12141	validation_1-rmse:36.55320
# [276]	validation_0-rmse:33.10772	validation_1-rmse:36.53997
# [277]	validation_0-rmse:33.09045	validation_1-rmse:36.52155
# [278]	validation_0-rmse:33.07223	validation_1-rmse:36.50369
# [279]	validation_0-rmse:33.05873	validation_1-rmse:36.48879
# [280]	validation_0-rmse:33.04568	validation_1-rmse:36.47832
# [281]	validation_0-rmse:33.03393	validation_1-rmse:36.46249
# [282]	validation_0-rmse:33.02298	validation_1-rmse:36.45067
# [283]	validation_0-rmse:33.01139	validation_1-rmse:36.43687
# [284]	validation_0-rmse:32.99780	validation_1-rmse:36.42110
# [285]	validation_0-rmse:32.98625	validation_1-rmse:36.40905
# [286]	validation_0-rmse:32.97429	validation_1-rmse:36.39480
# [287]	validation_0-rmse:32.95793	validation_1-rmse:36.37878
# [288]	validation_0-rmse:32.94548	validation_1-rmse:36.36648
# [289]	validation_0-rmse:32.92989	validation_1-rmse:36.34928
# [290]	validation_0-rmse:32.91919	validation_1-rmse:36.34036
# [291]	validation_0-rmse:32.90852	validation_1-rmse:36.32990
# [292]	validation_0-rmse:32.89819	validation_1-rmse:36.32169
# [293]	validation_0-rmse:32.88802	validation_1-rmse:36.31097
# [294]	validation_0-rmse:32.87694	validation_1-rmse:36.30228
# [295]	validation_0-rmse:32.86803	validation_1-rmse:36.29024
# [296]	validation_0-rmse:32.85862	validation_1-rmse:36.28238
# [297]	validation_0-rmse:32.84898	validation_1-rmse:36.27482
# [298]	validation_0-rmse:32.83758	validation_1-rmse:36.26245
# [299]	validation_0-rmse:32.82557	validation_1-rmse:36.24370
# [300]	validation_0-rmse:32.81112	validation_1-rmse:36.22722
# [301]	validation_0-rmse:32.80167	validation_1-rmse:36.21840
# [302]	validation_0-rmse:32.79254	validation_1-rmse:36.20975
# [303]	validation_0-rmse:32.78492	validation_1-rmse:36.20108
# [304]	validation_0-rmse:32.77451	validation_1-rmse:36.18895
# [305]	validation_0-rmse:32.76613	validation_1-rmse:36.18165
# [306]	validation_0-rmse:32.75570	validation_1-rmse:36.17098
# [307]	validation_0-rmse:32.74182	validation_1-rmse:36.15651
# [308]	validation_0-rmse:32.73053	validation_1-rmse:36.14080
# [309]	validation_0-rmse:32.72230	validation_1-rmse:36.13331
# [310]	validation_0-rmse:32.71304	validation_1-rmse:36.12288
# [311]	validation_0-rmse:32.70329	validation_1-rmse:36.11451
# [312]	validation_0-rmse:32.69206	validation_1-rmse:36.10340
# [313]	validation_0-rmse:32.68526	validation_1-rmse:36.09595
# [314]	validation_0-rmse:32.67670	validation_1-rmse:36.08658
# [315]	validation_0-rmse:32.66763	validation_1-rmse:36.07659
# [316]	validation_0-rmse:32.65494	validation_1-rmse:36.06030
# [317]	validation_0-rmse:32.64618	validation_1-rmse:36.05461
# [318]	validation_0-rmse:32.63967	validation_1-rmse:36.04979
# [319]	validation_0-rmse:32.62779	validation_1-rmse:36.03545
# [320]	validation_0-rmse:32.61917	validation_1-rmse:36.02538
# [321]	validation_0-rmse:32.60762	validation_1-rmse:36.01289
# [322]	validation_0-rmse:32.59985	validation_1-rmse:36.00611
# [323]	validation_0-rmse:32.59075	validation_1-rmse:35.99846
# [324]	validation_0-rmse:32.58238	validation_1-rmse:35.99232
# [325]	validation_0-rmse:32.57581	validation_1-rmse:35.98574
# [326]	validation_0-rmse:32.56966	validation_1-rmse:35.98126
# [327]	validation_0-rmse:32.55819	validation_1-rmse:35.97178
# [328]	validation_0-rmse:32.55130	validation_1-rmse:35.96608
# [329]	validation_0-rmse:32.54330	validation_1-rmse:35.95752
# [330]	validation_0-rmse:32.53398	validation_1-rmse:35.94815
# [331]	validation_0-rmse:32.52607	validation_1-rmse:35.94023
# [332]	validation_0-rmse:32.51696	validation_1-rmse:35.93045
# [333]	validation_0-rmse:32.50945	validation_1-rmse:35.92560
# [334]	validation_0-rmse:32.50411	validation_1-rmse:35.92084
# [335]	validation_0-rmse:32.49668	validation_1-rmse:35.91423
# [336]	validation_0-rmse:32.48922	validation_1-rmse:35.90680
# [337]	validation_0-rmse:32.48119	validation_1-rmse:35.90324
# [338]	validation_0-rmse:32.47377	validation_1-rmse:35.89502
# [339]	validation_0-rmse:32.46921	validation_1-rmse:35.89205
# [340]	validation_0-rmse:32.46315	validation_1-rmse:35.88713
# [341]	validation_0-rmse:32.45725	validation_1-rmse:35.88116
# [342]	validation_0-rmse:32.45134	validation_1-rmse:35.87643
# [343]	validation_0-rmse:32.44451	validation_1-rmse:35.87190
# [344]	validation_0-rmse:32.43436	validation_1-rmse:35.86050
# [345]	validation_0-rmse:32.42759	validation_1-rmse:35.85368
# [346]	validation_0-rmse:32.42144	validation_1-rmse:35.84970
# [347]	validation_0-rmse:32.41508	validation_1-rmse:35.84448
# [348]	validation_0-rmse:32.40760	validation_1-rmse:35.83758
# [349]	validation_0-rmse:32.40077	validation_1-rmse:35.83517
# [350]	validation_0-rmse:32.39449	validation_1-rmse:35.83133
# [351]	validation_0-rmse:32.38623	validation_1-rmse:35.82246
# [352]	validation_0-rmse:32.37902	validation_1-rmse:35.81689
# [353]	validation_0-rmse:32.37268	validation_1-rmse:35.80979
# [354]	validation_0-rmse:32.36531	validation_1-rmse:35.80720
# [355]	validation_0-rmse:32.35861	validation_1-rmse:35.80479
# [356]	validation_0-rmse:32.34978	validation_1-rmse:35.79560
# [357]	validation_0-rmse:32.34491	validation_1-rmse:35.79174
# [358]	validation_0-rmse:32.33932	validation_1-rmse:35.78784
# [359]	validation_0-rmse:32.33270	validation_1-rmse:35.78116
# [360]	validation_0-rmse:32.32679	validation_1-rmse:35.77731
# [361]	validation_0-rmse:32.32032	validation_1-rmse:35.77264
# [362]	validation_0-rmse:32.31319	validation_1-rmse:35.76389
# [363]	validation_0-rmse:32.30740	validation_1-rmse:35.75821
# [364]	validation_0-rmse:32.30321	validation_1-rmse:35.75525
# [365]	validation_0-rmse:32.29749	validation_1-rmse:35.75197
# [366]	validation_0-rmse:32.29106	validation_1-rmse:35.74759
# [367]	validation_0-rmse:32.28227	validation_1-rmse:35.74189
# [368]	validation_0-rmse:32.27754	validation_1-rmse:35.73877
# [369]	validation_0-rmse:32.27274	validation_1-rmse:35.73870
# [370]	validation_0-rmse:32.26742	validation_1-rmse:35.73759
# [371]	validation_0-rmse:32.26318	validation_1-rmse:35.73388
# [372]	validation_0-rmse:32.25735	validation_1-rmse:35.72951
# [373]	validation_0-rmse:32.25153	validation_1-rmse:35.72819
# [374]	validation_0-rmse:32.24532	validation_1-rmse:35.72735
# [375]	validation_0-rmse:32.23695	validation_1-rmse:35.71795
# [376]	validation_0-rmse:32.22850	validation_1-rmse:35.70640
# [377]	validation_0-rmse:32.22477	validation_1-rmse:35.70231
# [378]	validation_0-rmse:32.21634	validation_1-rmse:35.69491
# [379]	validation_0-rmse:32.20961	validation_1-rmse:35.68838
# [380]	validation_0-rmse:32.20416	validation_1-rmse:35.68708
# [381]	validation_0-rmse:32.19717	validation_1-rmse:35.67654
# [382]	validation_0-rmse:32.19332	validation_1-rmse:35.67340
# [383]	validation_0-rmse:32.18560	validation_1-rmse:35.66640
# [384]	validation_0-rmse:32.17938	validation_1-rmse:35.65918
# [385]	validation_0-rmse:32.17270	validation_1-rmse:35.65026
# [386]	validation_0-rmse:32.16499	validation_1-rmse:35.64280
# [387]	validation_0-rmse:32.15881	validation_1-rmse:35.63797
# [388]	validation_0-rmse:32.15484	validation_1-rmse:35.63456
# [389]	validation_0-rmse:32.14715	validation_1-rmse:35.62723
# [390]	validation_0-rmse:32.14254	validation_1-rmse:35.62403
# [391]	validation_0-rmse:32.13517	validation_1-rmse:35.61774
# [392]	validation_0-rmse:32.12986	validation_1-rmse:35.61403
# [393]	validation_0-rmse:32.12398	validation_1-rmse:35.61087
# [394]	validation_0-rmse:32.11839	validation_1-rmse:35.60842
# [395]	validation_0-rmse:32.11382	validation_1-rmse:35.60803
# [396]	validation_0-rmse:32.10865	validation_1-rmse:35.60193
# [397]	validation_0-rmse:32.10112	validation_1-rmse:35.59412
# [398]	validation_0-rmse:32.09666	validation_1-rmse:35.59045
# [399]	validation_0-rmse:32.09252	validation_1-rmse:35.58876
# [400]	validation_0-rmse:32.08669	validation_1-rmse:35.58092
# [401]	validation_0-rmse:32.08057	validation_1-rmse:35.57534
# [402]	validation_0-rmse:32.07555	validation_1-rmse:35.57318
# [403]	validation_0-rmse:32.07024	validation_1-rmse:35.56965
# [404]	validation_0-rmse:32.06591	validation_1-rmse:35.56732
# [405]	validation_0-rmse:32.06119	validation_1-rmse:35.56321
# [406]	validation_0-rmse:32.05750	validation_1-rmse:35.56149
# [407]	validation_0-rmse:32.05262	validation_1-rmse:35.56184
# [408]	validation_0-rmse:32.04836	validation_1-rmse:35.55661
# [409]	validation_0-rmse:32.04450	validation_1-rmse:35.55520
# [410]	validation_0-rmse:32.03954	validation_1-rmse:35.55396
# [411]	validation_0-rmse:32.03610	validation_1-rmse:35.54983
# [412]	validation_0-rmse:32.03191	validation_1-rmse:35.54794
# [413]	validation_0-rmse:32.02543	validation_1-rmse:35.54310
# [414]	validation_0-rmse:32.01873	validation_1-rmse:35.53803
# [415]	validation_0-rmse:32.01443	validation_1-rmse:35.53802
# [416]	validation_0-rmse:32.00786	validation_1-rmse:35.53168
# [417]	validation_0-rmse:32.00373	validation_1-rmse:35.53045
# [418]	validation_0-rmse:32.00080	validation_1-rmse:35.52937
# [419]	validation_0-rmse:31.99642	validation_1-rmse:35.52614
# [420]	validation_0-rmse:31.98939	validation_1-rmse:35.52063
# [421]	validation_0-rmse:31.98352	validation_1-rmse:35.51513
# [422]	validation_0-rmse:31.97811	validation_1-rmse:35.50736
# [423]	validation_0-rmse:31.97291	validation_1-rmse:35.50627
# [424]	validation_0-rmse:31.96835	validation_1-rmse:35.50359
# [425]	validation_0-rmse:31.96409	validation_1-rmse:35.50143
# [426]	validation_0-rmse:31.96045	validation_1-rmse:35.49900
# [427]	validation_0-rmse:31.95664	validation_1-rmse:35.49719
# [428]	validation_0-rmse:31.95347	validation_1-rmse:35.49601
# [429]	validation_0-rmse:31.94717	validation_1-rmse:35.49291
# [430]	validation_0-rmse:31.94323	validation_1-rmse:35.49225
# [431]	validation_0-rmse:31.93947	validation_1-rmse:35.48861
# [432]	validation_0-rmse:31.93573	validation_1-rmse:35.49010
# [433]	validation_0-rmse:31.93182	validation_1-rmse:35.48729
# [434]	validation_0-rmse:31.92724	validation_1-rmse:35.48262
# [435]	validation_0-rmse:31.92306	validation_1-rmse:35.48105
# [436]	validation_0-rmse:31.91925	validation_1-rmse:35.47970
# [437]	validation_0-rmse:31.91544	validation_1-rmse:35.47851
# [438]	validation_0-rmse:31.91302	validation_1-rmse:35.47803
# [439]	validation_0-rmse:31.90735	validation_1-rmse:35.47237
# [440]	validation_0-rmse:31.90309	validation_1-rmse:35.47142
# [441]	validation_0-rmse:31.89926	validation_1-rmse:35.47074
# [442]	validation_0-rmse:31.89464	validation_1-rmse:35.47128
# [443]	validation_0-rmse:31.89098	validation_1-rmse:35.46978
# [444]	validation_0-rmse:31.88463	validation_1-rmse:35.46646
# [445]	validation_0-rmse:31.87808	validation_1-rmse:35.46161
# [446]	validation_0-rmse:31.87419	validation_1-rmse:35.45901
# [447]	validation_0-rmse:31.87005	validation_1-rmse:35.45707
# [448]	validation_0-rmse:31.86698	validation_1-rmse:35.45538
# [449]	validation_0-rmse:31.86388	validation_1-rmse:35.45291
# [450]	validation_0-rmse:31.86024	validation_1-rmse:35.44996
# [451]	validation_0-rmse:31.85449	validation_1-rmse:35.44815
# [452]	validation_0-rmse:31.85109	validation_1-rmse:35.44527
# [453]	validation_0-rmse:31.84648	validation_1-rmse:35.44159
# [454]	validation_0-rmse:31.84111	validation_1-rmse:35.43854
# [455]	validation_0-rmse:31.83811	validation_1-rmse:35.43696
# [456]	validation_0-rmse:31.83623	validation_1-rmse:35.43583
# [457]	validation_0-rmse:31.83265	validation_1-rmse:35.43670
# [458]	validation_0-rmse:31.82964	validation_1-rmse:35.43465
# [459]	validation_0-rmse:31.82505	validation_1-rmse:35.43470
# [460]	validation_0-rmse:31.82098	validation_1-rmse:35.43181
# [461]	validation_0-rmse:31.81650	validation_1-rmse:35.42812
# [462]	validation_0-rmse:31.81279	validation_1-rmse:35.42842
# [463]	validation_0-rmse:31.81019	validation_1-rmse:35.42673
# [464]	validation_0-rmse:31.80622	validation_1-rmse:35.42349
# [465]	validation_0-rmse:31.80313	validation_1-rmse:35.42000
# [466]	validation_0-rmse:31.79810	validation_1-rmse:35.41637
# [467]	validation_0-rmse:31.79330	validation_1-rmse:35.41488
# [468]	validation_0-rmse:31.78998	validation_1-rmse:35.41414
# [469]	validation_0-rmse:31.78684	validation_1-rmse:35.41522
# [470]	validation_0-rmse:31.78241	validation_1-rmse:35.41368
# [471]	validation_0-rmse:31.77757	validation_1-rmse:35.41083
# [472]	validation_0-rmse:31.77455	validation_1-rmse:35.40781
# [473]	validation_0-rmse:31.77049	validation_1-rmse:35.40601
# [474]	validation_0-rmse:31.76751	validation_1-rmse:35.40452
# [475]	validation_0-rmse:31.76450	validation_1-rmse:35.40335
# [476]	validation_0-rmse:31.75933	validation_1-rmse:35.40139
# [477]	validation_0-rmse:31.75400	validation_1-rmse:35.39967
# [478]	validation_0-rmse:31.75134	validation_1-rmse:35.39961
# [479]	validation_0-rmse:31.74828	validation_1-rmse:35.39870
# [480]	validation_0-rmse:31.74521	validation_1-rmse:35.39871
# [481]	validation_0-rmse:31.74153	validation_1-rmse:35.39451
# [482]	validation_0-rmse:31.73803	validation_1-rmse:35.39496
# [483]	validation_0-rmse:31.73474	validation_1-rmse:35.39314
# [484]	validation_0-rmse:31.73157	validation_1-rmse:35.39387
# [485]	validation_0-rmse:31.72771	validation_1-rmse:35.39363
# [486]	validation_0-rmse:31.72453	validation_1-rmse:35.39388
# [487]	validation_0-rmse:31.72055	validation_1-rmse:35.39259
# [488]	validation_0-rmse:31.71763	validation_1-rmse:35.39278
# [489]	validation_0-rmse:31.71405	validation_1-rmse:35.39046
# [490]	validation_0-rmse:31.71068	validation_1-rmse:35.38700
# [491]	validation_0-rmse:31.70746	validation_1-rmse:35.38752
# [492]	validation_0-rmse:31.70348	validation_1-rmse:35.38337
# [493]	validation_0-rmse:31.69853	validation_1-rmse:35.38127
# [494]	validation_0-rmse:31.69424	validation_1-rmse:35.37771
# [495]	validation_0-rmse:31.69002	validation_1-rmse:35.37677
# [496]	validation_0-rmse:31.68593	validation_1-rmse:35.37334
# [497]	validation_0-rmse:31.68264	validation_1-rmse:35.37366
# [498]	validation_0-rmse:31.67890	validation_1-rmse:35.36947
# [499]	validation_0-rmse:31.67417	validation_1-rmse:35.36610
# [500]	validation_0-rmse:31.67075	validation_1-rmse:35.36919
# [501]	validation_0-rmse:31.66612	validation_1-rmse:35.36342
# [502]	validation_0-rmse:31.66364	validation_1-rmse:35.36280
# [503]	validation_0-rmse:31.66057	validation_1-rmse:35.36139
# [504]	validation_0-rmse:31.65787	validation_1-rmse:35.36138
# [505]	validation_0-rmse:31.65310	validation_1-rmse:35.35729
# [506]	validation_0-rmse:31.64849	validation_1-rmse:35.35412
# [507]	validation_0-rmse:31.64361	validation_1-rmse:35.35179
# [508]	validation_0-rmse:31.64056	validation_1-rmse:35.34961
# [509]	validation_0-rmse:31.63702	validation_1-rmse:35.34537
# [510]	validation_0-rmse:31.63237	validation_1-rmse:35.34429
# [511]	validation_0-rmse:31.62867	validation_1-rmse:35.33926
# [512]	validation_0-rmse:31.62493	validation_1-rmse:35.33884
# [513]	validation_0-rmse:31.62225	validation_1-rmse:35.33779
# [514]	validation_0-rmse:31.61837	validation_1-rmse:35.33882
# [515]	validation_0-rmse:31.61500	validation_1-rmse:35.33947
# [516]	validation_0-rmse:31.61115	validation_1-rmse:35.33494
# [517]	validation_0-rmse:31.60754	validation_1-rmse:35.33115
# [518]	validation_0-rmse:31.60312	validation_1-rmse:35.33025
# [519]	validation_0-rmse:31.59810	validation_1-rmse:35.32827
# [520]	validation_0-rmse:31.59543	validation_1-rmse:35.32813
# [521]	validation_0-rmse:31.59255	validation_1-rmse:35.32709
# [522]	validation_0-rmse:31.58835	validation_1-rmse:35.32521
# [523]	validation_0-rmse:31.58679	validation_1-rmse:35.32439
# [524]	validation_0-rmse:31.58389	validation_1-rmse:35.32418
# [525]	validation_0-rmse:31.57964	validation_1-rmse:35.32225
# [526]	validation_0-rmse:31.57630	validation_1-rmse:35.32241
# [527]	validation_0-rmse:31.57265	validation_1-rmse:35.31592
# [528]	validation_0-rmse:31.57075	validation_1-rmse:35.31614
# [529]	validation_0-rmse:31.56736	validation_1-rmse:35.31556
# [530]	validation_0-rmse:31.56394	validation_1-rmse:35.31559
# [531]	validation_0-rmse:31.55989	validation_1-rmse:35.31800
# [532]	validation_0-rmse:31.55686	validation_1-rmse:35.31803
# [533]	validation_0-rmse:31.55254	validation_1-rmse:35.31629
# [534]	validation_0-rmse:31.55073	validation_1-rmse:35.31748
# [535]	validation_0-rmse:31.54805	validation_1-rmse:35.31485
# [536]	validation_0-rmse:31.54397	validation_1-rmse:35.31362
# [537]	validation_0-rmse:31.54008	validation_1-rmse:35.31211
# [538]	validation_0-rmse:31.53665	validation_1-rmse:35.31030
# [539]	validation_0-rmse:31.53312	validation_1-rmse:35.30833
# [540]	validation_0-rmse:31.53068	validation_1-rmse:35.30894
# [541]	validation_0-rmse:31.52838	validation_1-rmse:35.30874
# [542]	validation_0-rmse:31.52497	validation_1-rmse:35.30875
# [543]	validation_0-rmse:31.52168	validation_1-rmse:35.30491
# [544]	validation_0-rmse:31.51893	validation_1-rmse:35.30208
# [545]	validation_0-rmse:31.51525	validation_1-rmse:35.30235
# [546]	validation_0-rmse:31.51251	validation_1-rmse:35.30362
# [547]	validation_0-rmse:31.51002	validation_1-rmse:35.30120
# [548]	validation_0-rmse:31.50655	validation_1-rmse:35.29948
# [549]	validation_0-rmse:31.50232	validation_1-rmse:35.29822
# [550]	validation_0-rmse:31.49896	validation_1-rmse:35.29621
# [551]	validation_0-rmse:31.49569	validation_1-rmse:35.29407
# [552]	validation_0-rmse:31.49216	validation_1-rmse:35.29285
# [553]	validation_0-rmse:31.48993	validation_1-rmse:35.29226
# [554]	validation_0-rmse:31.48687	validation_1-rmse:35.29364
# [555]	validation_0-rmse:31.48292	validation_1-rmse:35.29407
# [556]	validation_0-rmse:31.48045	validation_1-rmse:35.29317
# [557]	validation_0-rmse:31.47797	validation_1-rmse:35.29260
# [558]	validation_0-rmse:31.47539	validation_1-rmse:35.29204
# [559]	validation_0-rmse:31.47363	validation_1-rmse:35.29063
# [560]	validation_0-rmse:31.47000	validation_1-rmse:35.28783
# [561]	validation_0-rmse:31.46737	validation_1-rmse:35.28650
# [562]	validation_0-rmse:31.46504	validation_1-rmse:35.28623
# [563]	validation_0-rmse:31.46137	validation_1-rmse:35.28738
# [564]	validation_0-rmse:31.45894	validation_1-rmse:35.28756
# [565]	validation_0-rmse:31.45645	validation_1-rmse:35.28768
# [566]	validation_0-rmse:31.45336	validation_1-rmse:35.28721
# [567]	validation_0-rmse:31.44979	validation_1-rmse:35.28611
# [568]	validation_0-rmse:31.44626	validation_1-rmse:35.28569
# [569]	validation_0-rmse:31.44373	validation_1-rmse:35.28326
# [570]	validation_0-rmse:31.44076	validation_1-rmse:35.28102
# [571]	validation_0-rmse:31.43699	validation_1-rmse:35.28000
# [572]	validation_0-rmse:31.43445	validation_1-rmse:35.27875
# [573]	validation_0-rmse:31.43226	validation_1-rmse:35.27820
# [574]	validation_0-rmse:31.42884	validation_1-rmse:35.27661
# [575]	validation_0-rmse:31.42550	validation_1-rmse:35.27237
# [576]	validation_0-rmse:31.42293	validation_1-rmse:35.27135
# [577]	validation_0-rmse:31.41991	validation_1-rmse:35.27303
# [578]	validation_0-rmse:31.41719	validation_1-rmse:35.27390
# [579]	validation_0-rmse:31.41412	validation_1-rmse:35.27366
# [580]	validation_0-rmse:31.41212	validation_1-rmse:35.27209
# [581]	validation_0-rmse:31.40914	validation_1-rmse:35.27035
# [582]	validation_0-rmse:31.40622	validation_1-rmse:35.26943
# [583]	validation_0-rmse:31.40552	validation_1-rmse:35.26879
# [584]	validation_0-rmse:31.40250	validation_1-rmse:35.26538
# [585]	validation_0-rmse:31.39995	validation_1-rmse:35.26598
# [586]	validation_0-rmse:31.39616	validation_1-rmse:35.26399
# [587]	validation_0-rmse:31.39324	validation_1-rmse:35.26508
# [588]	validation_0-rmse:31.38998	validation_1-rmse:35.26417
# [589]	validation_0-rmse:31.38784	validation_1-rmse:35.26278
# [590]	validation_0-rmse:31.38435	validation_1-rmse:35.25841
# [591]	validation_0-rmse:31.38174	validation_1-rmse:35.25722
# [592]	validation_0-rmse:31.37989	validation_1-rmse:35.25865
# [593]	validation_0-rmse:31.37749	validation_1-rmse:35.26024
# [594]	validation_0-rmse:31.37433	validation_1-rmse:35.25810
# [595]	validation_0-rmse:31.37086	validation_1-rmse:35.25773
# [596]	validation_0-rmse:31.36837	validation_1-rmse:35.25841
# [597]	validation_0-rmse:31.36643	validation_1-rmse:35.25684
# [598]	validation_0-rmse:31.36329	validation_1-rmse:35.25604
# [599]	validation_0-rmse:31.35995	validation_1-rmse:35.25407
# [600]	validation_0-rmse:31.35671	validation_1-rmse:35.24988
# [601]	validation_0-rmse:31.35326	validation_1-rmse:35.25025
# [602]	validation_0-rmse:31.34969	validation_1-rmse:35.24880
# [603]	validation_0-rmse:31.34698	validation_1-rmse:35.24840
# [604]	validation_0-rmse:31.34319	validation_1-rmse:35.24888
# [605]	validation_0-rmse:31.33943	validation_1-rmse:35.24819
# [606]	validation_0-rmse:31.33586	validation_1-rmse:35.24788
# [607]	validation_0-rmse:31.33215	validation_1-rmse:35.24577
# [608]	validation_0-rmse:31.32903	validation_1-rmse:35.24593
# [609]	validation_0-rmse:31.32590	validation_1-rmse:35.24517
# [610]	validation_0-rmse:31.32299	validation_1-rmse:35.24622
# [611]	validation_0-rmse:31.31996	validation_1-rmse:35.24493
# [612]	validation_0-rmse:31.31803	validation_1-rmse:35.24678
# [613]	validation_0-rmse:31.31500	validation_1-rmse:35.24553
# [614]	validation_0-rmse:31.31251	validation_1-rmse:35.24359
# [615]	validation_0-rmse:31.30982	validation_1-rmse:35.24281
# [616]	validation_0-rmse:31.30736	validation_1-rmse:35.24379
# [617]	validation_0-rmse:31.30532	validation_1-rmse:35.24255
# [618]	validation_0-rmse:31.30309	validation_1-rmse:35.24079
# [619]	validation_0-rmse:31.30017	validation_1-rmse:35.24095
# [620]	validation_0-rmse:31.29814	validation_1-rmse:35.24171
# [621]	validation_0-rmse:31.29554	validation_1-rmse:35.24135
# [622]	validation_0-rmse:31.29231	validation_1-rmse:35.23953
# [623]	validation_0-rmse:31.29170	validation_1-rmse:35.23988
# [624]	validation_0-rmse:31.28805	validation_1-rmse:35.23856
# [625]	validation_0-rmse:31.28506	validation_1-rmse:35.23877
# [626]	validation_0-rmse:31.28288	validation_1-rmse:35.23799
# [627]	validation_0-rmse:31.28005	validation_1-rmse:35.23684
# [628]	validation_0-rmse:31.27723	validation_1-rmse:35.23844
# [629]	validation_0-rmse:31.27524	validation_1-rmse:35.23923
# [630]	validation_0-rmse:31.27341	validation_1-rmse:35.23824
# [631]	validation_0-rmse:31.27016	validation_1-rmse:35.23681
# [632]	validation_0-rmse:31.26690	validation_1-rmse:35.23537
# [633]	validation_0-rmse:31.26334	validation_1-rmse:35.23577
# [634]	validation_0-rmse:31.26093	validation_1-rmse:35.23661
# [635]	validation_0-rmse:31.25719	validation_1-rmse:35.23329
# [636]	validation_0-rmse:31.25397	validation_1-rmse:35.23320
# [637]	validation_0-rmse:31.25099	validation_1-rmse:35.23151
# [638]	validation_0-rmse:31.24867	validation_1-rmse:35.23067
# [639]	validation_0-rmse:31.24532	validation_1-rmse:35.22995
# [640]	validation_0-rmse:31.24354	validation_1-rmse:35.22873
# [641]	validation_0-rmse:31.24045	validation_1-rmse:35.22710
# [642]	validation_0-rmse:31.23774	validation_1-rmse:35.22715
# [643]	validation_0-rmse:31.23698	validation_1-rmse:35.22674
# [644]	validation_0-rmse:31.23380	validation_1-rmse:35.22659
# [645]	validation_0-rmse:31.23082	validation_1-rmse:35.22337
# [646]	validation_0-rmse:31.22799	validation_1-rmse:35.22375
# [647]	validation_0-rmse:31.22671	validation_1-rmse:35.22369
# [648]	validation_0-rmse:31.22344	validation_1-rmse:35.22185
# [649]	validation_0-rmse:31.22213	validation_1-rmse:35.22090
# [650]	validation_0-rmse:31.21943	validation_1-rmse:35.22078
# [651]	validation_0-rmse:31.21773	validation_1-rmse:35.21989
# [652]	validation_0-rmse:31.21619	validation_1-rmse:35.21938
# [653]	validation_0-rmse:31.21479	validation_1-rmse:35.21930
# [654]	validation_0-rmse:31.21214	validation_1-rmse:35.21955
# [655]	validation_0-rmse:31.20929	validation_1-rmse:35.21910
# [656]	validation_0-rmse:31.20713	validation_1-rmse:35.21780
# [657]	validation_0-rmse:31.20398	validation_1-rmse:35.21417
# [658]	validation_0-rmse:31.20085	validation_1-rmse:35.21167
# [659]	validation_0-rmse:31.19808	validation_1-rmse:35.21147
# [660]	validation_0-rmse:31.19749	validation_1-rmse:35.21120
# [661]	validation_0-rmse:31.19464	validation_1-rmse:35.20962
# [662]	validation_0-rmse:31.19206	validation_1-rmse:35.21124
# [663]	validation_0-rmse:31.18951	validation_1-rmse:35.21140
# [664]	validation_0-rmse:31.18643	validation_1-rmse:35.21075
# [665]	validation_0-rmse:31.18282	validation_1-rmse:35.21172
# [666]	validation_0-rmse:31.18031	validation_1-rmse:35.21159
# [667]	validation_0-rmse:31.17908	validation_1-rmse:35.21142
# [668]	validation_0-rmse:31.17603	validation_1-rmse:35.20155
# [669]	validation_0-rmse:31.17354	validation_1-rmse:35.19943
# [670]	validation_0-rmse:31.17271	validation_1-rmse:35.19849
# [671]	validation_0-rmse:31.17199	validation_1-rmse:35.19909
# [672]	validation_0-rmse:31.16950	validation_1-rmse:35.20128
# [673]	validation_0-rmse:31.16735	validation_1-rmse:35.20187
# [674]	validation_0-rmse:31.16505	validation_1-rmse:35.20223
# [675]	validation_0-rmse:31.16279	validation_1-rmse:35.20216
# [676]	validation_0-rmse:31.16090	validation_1-rmse:35.20224
# [677]	validation_0-rmse:31.15964	validation_1-rmse:35.20272
# [678]	validation_0-rmse:31.15891	validation_1-rmse:35.20262
# [679]	validation_0-rmse:31.15731	validation_1-rmse:35.20288
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.2, gamma=0.2, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=5,
#              min_child_weight=3, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
pred=pd.Series(xgb_model.predict(X_val),index=y_val.index)
rmse=np.sqrt(mean_squared_error(y_val,pred))
print(rmse)
# Out:
# 35.19849665541196

# %%
y_val.plot(figsize=(12,5),alpha=0.5,label='y_val');
pred.plot(alpha=1,color='orange',label='y_val_pred')
plt.legend();

# %%
X_train2=pd.concat([X_train,X_val],axis=0)
y_train2=pd.concat([y_train,y_val],axis=0)

# predict next 649 values for X_test
# xgb_model.predict(X_train2.iloc[-1:])[0]
# Out:
# 55.89276

# %%
# n_steps=20
# X_ex=X_train2.copy(deep=True).reset_index().drop('combined_date',axis=1)
# y_ex=y_train2.copy(deep=True).values

# for i in range(n_steps):
#     x1=X_ex.iloc[-1:].reset_index().drop('index',axis=1)

#     x1.loc[0,'time1']+=1

#     for i in range(1,31):
#         x1.loc[0,'demand_lag_'+str(i)]=y_ex[-i]

#     y_ex=np.append(y_ex,xgb_model.predict(x1)[0])
#     X_ex=pd.concat([X_ex,x1],axis=0)
# Out:
# array([69.8442688, 69.8442688, 69.8442688, 69.8442688, 69.8442688])
